# %%
class Solution:
    def subtractProductAndSum(self, n: int) -> int:
        p=1
        s=0
        for i in str(n):
            d = int(i)
            p*=d
            s+=d
        v=p-s
        return v
